# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
path_to_csv = '/content/gdrive/My Drive/breastcancer.csv'

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from keras.layers import Dense

# Load dataset
path_to_csv = '/content/gdrive/My Drive/breastcancer.csv'
dataset = pd.read_csv(path_to_csv, header=0)

# Drop the 'id' and 'Unnamed: 32' columns as they are not needed
data = dataset.drop(columns=['id', 'Unnamed: 32'])

# Encode the target variable 'diagnosis' (M=1, B=0)
data['diagnosis'] = LabelEncoder().fit_transform(data['diagnosis'])

# Split the data into features and target
X = data.drop(columns=['diagnosis'])
y = data['diagnosis']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=87)

# Set random seed for reproducibility
np.random.seed(155)

# Create the neural network model
my_first_nn = Sequential()
my_first_nn.add(Dense(30, input_dim=X_train.shape[1], activation='relu'))  # Hidden layer
my_first_nn.add(Dense(1, activation='sigmoid'))  # Output layer

# Compile the model
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

# Fit the model
my_first_nn_fitted = my_first_nn.fit(X_train, y_train, epochs=100, initial_epoch=0)

# Print model summary
print(my_first_nn.summary())

# Evaluate the model
print(my_first_nn.evaluate(X_test, y_test))
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 2ms/step - loss: 3.5073 - acc: 0.8286
# Epoch 2/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.5045 - acc: 0.8427
# Epoch 3/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2288 - acc: 0.8779
# Epoch 4/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.0895 - acc: 0.8991
# Epoch 5/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.0271 - acc: 0.8967
# Epoch 6/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9955 - acc: 0.9061
# Epoch 7/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9573 - acc: 0.9085
# Epoch 8/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9438 - acc: 0.8873
# Epoch 9/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9027 - acc: 0.9131
# Epoch 10/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9019 - acc: 0.8967
# Epoch 11/100
# ...

# %%
#Normalize the data


import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from keras.models import Sequential
from keras.layers import Dense

# Load dataset
path_to_csv = '/content/gdrive/My Drive/breastcancer.csv'
dataset = pd.read_csv(path_to_csv, header=0)

# Drop the 'id' and 'Unnamed: 32' columns as they are not needed
data = dataset.drop(columns=['id', 'Unnamed: 32'])

# Encode the target variable 'diagnosis' (M=1, B=0)
data['diagnosis'] = LabelEncoder().fit_transform(data['diagnosis'])

# Split the data into features and target
X = data.drop(columns=['diagnosis'])
y = data['diagnosis']

# Normalize the data
sc = StandardScaler()
X = sc.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=87)

# Set random seed for reproducibility
np.random.seed(155)

# Create the neural network model
my_first_nn = Sequential()
my_first_nn.add(Dense(30, input_dim=X_train.shape[1], activation='relu'))  # Hidden layer
my_first_nn.add(Dense(1, activation='sigmoid'))  # Output layer

# Compile the model
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

# Fit the model
my_first_nn_fitted = my_first_nn.fit(X_train, y_train, epochs=100, initial_epoch=0)

# Print model summary
print(my_first_nn.summary())

# Evaluate the model
accuracy = my_first_nn.evaluate(X_test, y_test)
print(f"Accuracy: {accuracy[1]}")  # Print the accuracy
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 2ms/step - loss: 0.5998 - acc: 0.7324
# Epoch 2/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3790 - acc: 0.8474
# Epoch 3/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2727 - acc: 0.9272
# Epoch 4/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2193 - acc: 0.9413
# Epoch 5/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1884 - acc: 0.9484
# Epoch 6/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1677 - acc: 0.9507
# Epoch 7/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1520 - acc: 0.9507
# Epoch 8/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1392 - acc: 0.9507
# Epoch 9/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1288 - acc: 0.9531
# Epoch 10/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1203 - acc: 0.9624
# Epoch 11/100
# ...
